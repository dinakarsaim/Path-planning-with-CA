# %%
# !python /kaggle/input/modified-d3qn/env.py

# %%
# !python /kaggle/input/modified-d3qn/Agent.py

# %%
# !python /kaggle/input/modified-d3qn/D3QN_train.py
# Out:
# Episode 0, Reward: -4173.0, Steps: 1284, Epsilon: 0.598
# Episode 10, Reward: -670.0, Steps: 175, Epsilon: 0.578
# Episode 20, Reward: -853.5, Steps: 350, Epsilon: 0.5579999999999999
# Episode 30, Reward: -127.0, Steps: 62, Epsilon: 0.5379999999999999
# Episode 40, Reward: -103.5, Steps: 58, Epsilon: 0.5179999999999999
# Episode 50, Reward: -78.0, Steps: 20, Epsilon: 0.4979999999999999
# Episode 60, Reward: -55.5, Steps: 34, Epsilon: 0.47799999999999987
# Episode 70, Reward: -39.5, Steps: 20, Epsilon: 0.45799999999999985
# Episode 80, Reward: -10.5, Steps: 27, Epsilon: 0.43799999999999983
# Episode 90, Reward: -20.0, Steps: 34, Epsilon: 0.4179999999999998
# Episode 100, Reward: -67.5, Steps: 42, Epsilon: 0.3979999999999998
# Episode 110, Reward: -39.0, Steps: 18, Epsilon: 0.3779999999999998
# Episode 120, Reward: -61.5, Steps: 36, Epsilon: 0.35799999999999976
# Episode 130, Reward: -20.0, Steps: 19, Epsilon: 0.33799999999999975
# ...

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/d3qn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[3]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('accumulated rewards')
graph.title('d3qn')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/d3qn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[1]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('steps taken')
graph.title('d3qn')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/d3qn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[2]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('time taken(ms)')
graph.title('d3qn')
graph.legend()
graph.show()

# %%
# %cd /kaggle/input/modified-d3qn
# Out:
# /kaggle/input/modified-d3qn

# %%
import csv
import matplotlib.pyplot as graph
import numpy
from env import obstacle_width
from env import Obstacleacc
obcoords = Obstacleacc()
x_o = obcoords.xpart
y_o = obcoords.ypart
with open('/kaggle/working/d3qn_final_path.csv') as file:
    reader  = csv.reader(file)
    for row in reader:
        finalx = numpy.array(list(map(int,row)))
        break
    for row in reader:
        finaly = numpy.array(list(map(int,row)))
        break
graph.figure()
graph.quiver(finalx[:-1],finaly[:-1],finalx[1:]-finalx[:-1],finaly[1:]-finaly[:-1], scale_units='xy', angles='xy', scale=1, color='black')
for i in range(len(x_o)):
    rectangle = graph.Rectangle(( 10* (x_o[i]-0.5), 10*(10 - y_o[i] -0.5)), obstacle_width, obstacle_width, fc='blue',ec="blue")
    graph.gca().add_patch(rectangle)
graph.scatter(10,0, marker = "s", ec = 'k', c ='red', s=100, label ="Start")
graph.scatter(90,100, marker = "s", ec = 'k', c ='red', s =100,label="Target")
graph.grid(linestyle=':')
graph.xlim(0,100)
graph.ylim(0,100)
graph.xlabel('x (m)',size = '14')
graph.ylabel('y (m)',size = '14')
graph.gca().set_aspect('equal', adjustable='box')
graph.show()

# %%
# !python /kaggle/input/modified-d3qn/DDQN_train.py
# Out:
# Episode 0, Reward: -3793.5, Steps: 1210, Epsilon: 0.598
# Episode 10, Reward: -112.0, Steps: 33, Epsilon: 0.578
# Episode 20, Reward: -186.5, Steps: 94, Epsilon: 0.5579999999999999
# Episode 30, Reward: -51.5, Steps: 29, Epsilon: 0.5379999999999999
# Episode 40, Reward: -78.0, Steps: 50, Epsilon: 0.5179999999999999
# Episode 50, Reward: -92.5, Steps: 33, Epsilon: 0.4979999999999999
# Episode 60, Reward: -62.5, Steps: 37, Epsilon: 0.47799999999999987
# Episode 70, Reward: -40.5, Steps: 35, Epsilon: 0.45799999999999985
# Episode 80, Reward: -91.0, Steps: 32, Epsilon: 0.43799999999999983
# Episode 90, Reward: -21.0, Steps: 35, Epsilon: 0.4179999999999998
# Episode 100, Reward: -137.0, Steps: 37, Epsilon: 0.3979999999999998
# Episode 110, Reward: -64.5, Steps: 23, Epsilon: 0.3779999999999998
# Episode 120, Reward: -32.5, Steps: 31, Epsilon: 0.35799999999999976
# Episode 130, Reward: -32.0, Steps: 29, Epsilon: 0.33799999999999975
# ...

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/ddqn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[3]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('accumulated rewards')
graph.title('ddqn')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/ddqn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[1]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('steps taken')
graph.title('ddqn')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/ddqn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[2]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('time taken')
graph.title('ddqn')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
import numpy
from env import obstacle_width
from env import Obstacleacc
obcoords = Obstacleacc()
x_o = obcoords.xpart
y_o = obcoords.ypart
with open('/kaggle/working/ddqn_final_path.csv') as file:
    reader  = csv.reader(file)
    for row in reader:
        finalx = numpy.array(list(map(int,row)))
        break
    for row in reader:
        finaly = numpy.array(list(map(int,row)))
        break
graph.figure()
graph.quiver(finalx[:-1],finaly[:-1],finalx[1:]-finalx[:-1],finaly[1:]-finaly[:-1], scale_units='xy', angles='xy', scale=1, color='black')
for i in range(len(x_o)):
    rectangle = graph.Rectangle(( 10* (x_o[i]-0.5), 10*(10 - y_o[i] -0.5)), obstacle_width, obstacle_width, fc='blue',ec="blue")
    graph.gca().add_patch(rectangle)
graph.scatter(10,0, marker = "s", ec = 'k', c ='red', s=100, label ="Start")
graph.scatter(90,100, marker = "s", ec = 'k', c ='red', s =100,label="Target")
graph.grid(linestyle=':')
graph.xlim(0,100)
graph.ylim(0,100)
graph.xlabel('x (m)',size = '14')
graph.ylabel('y (m)',size = '14')
graph.gca().set_aspect('equal', adjustable='box')
graph.show()

# %%
# !python /kaggle/input/modified-d3qn/AgentWithCA.py

# %%
# !python /kaggle/input/modified-d3qn/D3QNWithCA.py
# Out:
# Episode 0, Reward: -2166.0, Steps: 992, Epsilon: 0.598
# Episode 10, Reward: -512.5, Steps: 183, Epsilon: 0.578
# Episode 20, Reward: -42.0, Steps: 22, Epsilon: 0.5579999999999999
# Episode 30, Reward: -221.5, Steps: 81, Epsilon: 0.5379999999999999
# Episode 40, Reward: -341.5, Steps: 66, Epsilon: 0.5179999999999999
# Episode 50, Reward: -177.5, Steps: 53, Epsilon: 0.4979999999999999
# Episode 60, Reward: -91.5, Steps: 47, Epsilon: 0.47799999999999987
# Episode 70, Reward: -207.5, Steps: 50, Epsilon: 0.45799999999999985
# Episode 80, Reward: -51.5, Steps: 30, Epsilon: 0.43799999999999983
# Episode 90, Reward: -198.0, Steps: 41, Epsilon: 0.4179999999999998
# Episode 100, Reward: -100.5, Steps: 38, Epsilon: 0.3979999999999998
# Episode 110, Reward: -103.5, Steps: 41, Epsilon: 0.3779999999999998
# Episode 120, Reward: -66.5, Steps: 27, Epsilon: 0.35799999999999976
# Episode 130, Reward: -72.5, Steps: 29, Epsilon: 0.33799999999999975
# ...

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/d3qn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[3]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('accumulated rewards')
graph.title('d3qn with ca')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/d3qn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[1]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('steps taken')
graph.title('d3qn with CA')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/d3qn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[2]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('time taken')
graph.title('d3qn with CA')
graph.legend()
graph.show()

# %%
# %cd /kaggle/input/modified-d3qn
# Out:
# /kaggle/input/modified-d3qn

# %%
import csv
import matplotlib.pyplot as graph
import numpy
from env import obstacle_width
from env import Obstacleacc
obcoords = Obstacleacc()
x_o = obcoords.xpart
y_o = obcoords.ypart
with open('/kaggle/working/d3qn_withCA_final_path.csv') as file:
    reader  = csv.reader(file)
    for row in reader:
        finalx = numpy.array(list(map(int,row)))
        break
    for row in reader:
        finaly = numpy.array(list(map(int,row)))
        break
graph.figure()
graph.quiver(finalx[:-1],finaly[:-1],finalx[1:]-finalx[:-1],finaly[1:]-finaly[:-1], scale_units='xy', angles='xy', scale=1, color='black')
for i in range(len(x_o)):
    rectangle = graph.Rectangle(( 10* (x_o[i]-0.5), 10*(10 - y_o[i] -0.5)), obstacle_width, obstacle_width, fc='blue',ec="blue")
    graph.gca().add_patch(rectangle)
graph.scatter(10,0, marker = "s", ec = 'k', c ='red', s=100, label ="Start")
graph.scatter(90,100, marker = "s", ec = 'k', c ='red', s =100,label="Target")
graph.grid(linestyle=':')
graph.xlim(0,100)
graph.ylim(0,100)
graph.xlabel('x (m)',size = '14')
graph.ylabel('y (m)',size = '14')
graph.gca().set_aspect('equal', adjustable='box')
graph.show()

# %%
# !python /kaggle/input/modified-d3qn/DDQNWithCA.py
# Out:
# Episode 0, Reward: -8469.5, Steps: 2145, Epsilon: 0.598
# Episode 10, Reward: -316.5, Steps: 115, Epsilon: 0.578
# Episode 20, Reward: -1993.0, Steps: 565, Epsilon: 0.5579999999999999
# Episode 30, Reward: -544.0, Steps: 246, Epsilon: 0.5379999999999999
# Episode 40, Reward: -216.5, Steps: 25, Epsilon: 0.5179999999999999
# Episode 50, Reward: -325.5, Steps: 84, Epsilon: 0.4979999999999999
# Episode 60, Reward: -75.5, Steps: 34, Epsilon: 0.47799999999999987
# Episode 70, Reward: -260.5, Steps: 30, Epsilon: 0.45799999999999985
# Episode 80, Reward: -61.0, Steps: 52, Epsilon: 0.43799999999999983
# Episode 90, Reward: -830.0, Steps: 463, Epsilon: 0.4179999999999998
# Episode 100, Reward: -112.0, Steps: 84, Epsilon: 0.3979999999999998
# Episode 110, Reward: -190.5, Steps: 70, Epsilon: 0.3779999999999998
# Episode 120, Reward: -203.5, Steps: 84, Epsilon: 0.35799999999999976
# Episode 130, Reward: -102.5, Steps: 98, Epsilon: 0.33799999999999975
# ...

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/ddqn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[3]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('accumulated rewards')
graph.title('ddqn with channel atterntion')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/ddqn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[1]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('steps taken')
graph.title('ddqn with channel atterntion')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/ddqn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[2]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('time taken')
graph.title('ddqn with channel atterntion')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
import numpy
from env import obstacle_width
from env import Obstacleacc
obcoords = Obstacleacc()
x_o = obcoords.xpart
y_o = obcoords.ypart
with open('/kaggle/working/d3qn_withCA_final_path.csv') as file:
    reader  = csv.reader(file)
    for row in reader:
        finalx = numpy.array(list(map(int,row)))
        break
    for row in reader:
        finaly = numpy.array(list(map(int,row)))
        break
graph.figure()
graph.quiver(finalx[:-1],finaly[:-1],finalx[1:]-finalx[:-1],finaly[1:]-finaly[:-1], scale_units='xy', angles='xy', scale=1, color='black')
for i in range(len(x_o)):
    rectangle = graph.Rectangle(( 10* (x_o[i]-0.5), 10*(10 - y_o[i] -0.5)), obstacle_width, obstacle_width, fc='blue',ec="blue")
    graph.gca().add_patch(rectangle)
graph.scatter(10,0, marker = "s", ec = 'k', c ='red', s=100, label ="Start")
graph.scatter(90,100, marker = "s", ec = 'k', c ='red', s =100,label="Target")
graph.grid(linestyle=':')
graph.xlim(0,100)
graph.ylim(0,100)
graph.xlabel('x (m)',size = '14')
graph.ylabel('y (m)',size = '14')
graph.gca().set_aspect('equal', adjustable='box')
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
d3qnlist = list()
d3qncalist = list()
with open('/kaggle/working/d3qn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:d3qncalist.append(float(row[3]))
with open('/kaggle/working/d3qn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:d3qnlist.append(float(row[3]))
graph.plot(range(len(d3qnlist)),d3qnlist,color='blue')
graph.plot(range(len(d3qncalist)),d3qncalist,color='red')
graph.xlabel('ep')
graph.ylabel('accumulated rewards')
graph.title('d3qn vs d3qn with ca')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
d3qnlist = list()
d3qncalist = list()
with open('/kaggle/working/d3qn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:d3qncalist.append(float(row[1]))
with open('/kaggle/working/d3qn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:d3qnlist.append(float(row[1]))
graph.plot(range(len(d3qnlist)),d3qnlist,color='blue')
graph.plot(range(len(d3qncalist)),d3qncalist,color='red')
graph.xlabel('ep')
graph.ylabel('steps taken')
graph.title('d3qn vs d3qn with ca')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
d3qnlist = list()
d3qncalist = list()
with open('/kaggle/working/d3qn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:d3qncalist.append(float(row[2]))
with open('/kaggle/working/d3qn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:d3qnlist.append(float(row[2]))
graph.plot(range(len(d3qnlist)),d3qnlist,color='blue')
graph.plot(range(len(d3qncalist)),d3qncalist,color='red')
graph.xlabel('ep')
graph.ylabel('time taken')
graph.title('d3qn vs d3qn with ca')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
import numpy
from env import obstacle_width
from env import Obstacleacc
obcoords = Obstacleacc()
x_o = obcoords.xpart
y_o = obcoords.ypart
with open('/kaggle/working/d3qn_withCA_final_path.csv') as file:
    reader  = csv.reader(file)
    for row in reader:
        finalx = numpy.array(list(map(int,row)))
        break
    for row in reader:
        finaly = numpy.array(list(map(int,row)))
        break
graph.figure()
graph.quiver(finalx[:-1],finaly[:-1],finalx[1:]-finalx[:-1],finaly[1:]-finaly[:-1], scale_units='xy', angles='xy', scale=1, color='blue')
with open('/kaggle/working/d3qn_final_path.csv') as file:
    reader  = csv.reader(file)
    for row in reader:
        finalx = numpy.array(list(map(int,row)))
        break
    for row in reader:
        finaly = numpy.array(list(map(int,row)))
        break
graph.quiver(finalx[:-1],finaly[:-1],finalx[1:]-finalx[:-1],finaly[1:]-finaly[:-1], scale_units='xy', angles='xy', scale=1, color='red')
for i in range(len(x_o)):
    rectangle = graph.Rectangle(( 10* (x_o[i]-0.5), 10*(10 - y_o[i] -0.5)), obstacle_width, obstacle_width, fc='blue',ec="blue")
    graph.gca().add_patch(rectangle)
graph.scatter(10,0, marker = "s", ec = 'k', c ='red', s=100, label ="Start")
graph.scatter(90,100, marker = "s", ec = 'k', c ='red', s =100,label="Target")
graph.grid(linestyle=':')
graph.xlim(0,100)
graph.ylim(0,100)
graph.xlabel('x (m)',size = '14')
graph.ylabel('y (m)',size = '14')
graph.gca().set_aspect('equal', adjustable='box')
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
ddqncalist = list()
with open('/kaggle/working/ddqn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqncalist.append(float(row[3]))
with open('/kaggle/working/ddqn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[3]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='blue')
graph.plot(range(len(ddqncalist)),ddqncalist,color='red')
graph.xlabel('ep')
graph.ylabel('accumulated rewards')
graph.title('ddqn vs ddqn with ca')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
ddqncalist = list()
with open('/kaggle/working/ddqn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqncalist.append(float(row[1]))
with open('/kaggle/working/ddqn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[1]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='blue')
graph.plot(range(len(ddqncalist)),ddqncalist,color='red')
graph.xlabel('ep')
graph.ylabel('steps taken')
graph.title('ddqn vs ddqn with ca')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
ddqncalist = list()
with open('/kaggle/working/ddqn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqncalist.append(float(row[2]))
with open('/kaggle/working/ddqn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[2]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='blue')
graph.plot(range(len(ddqncalist)),ddqncalist,color='red')
graph.xlabel('ep')
graph.ylabel('time taken')
graph.title('ddqn vs ddqn with ca')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
import numpy
from env import obstacle_width
from env import Obstacleacc
obcoords = Obstacleacc()
x_o = obcoords.xpart
y_o = obcoords.ypart
with open('/kaggle/working/ddqn_final_path.csv') as file:
    reader  = csv.reader(file)
    for row in reader:
        finalx = numpy.array(list(map(int,row)))
        break
    for row in reader:
        finaly = numpy.array(list(map(int,row)))
        break
graph.figure()
graph.quiver(finalx[:-1],finaly[:-1],finalx[1:]-finalx[:-1],finaly[1:]-finaly[:-1], scale_units='xy', angles='xy', scale=1, color='blue')
with open('/kaggle/working/ddqn_withCA_final_path.csv') as file:
    reader  = csv.reader(file)
    for row in reader:
        finalcx = numpy.array(list(map(int,row)))
        break
    for row in reader:
        finalcy = numpy.array(list(map(int,row)))
        break
colour = 'red'
if list(finalcx) == list(finalx) and list(finalcy) == list(finaly):colour = 'purple'
graph.quiver(finalx[:-1],finaly[:-1],finalx[1:]-finalx[:-1],finaly[1:]-finaly[:-1], scale_units='xy', angles='xy', scale=1, color=colour)
for i in range(len(x_o)):
    rectangle = graph.Rectangle(( 10* (x_o[i]-0.5), 10*(10 - y_o[i] -0.5)), obstacle_width, obstacle_width, fc='blue',ec="blue")
    graph.gca().add_patch(rectangle)
graph.scatter(10,0, marker = "s", ec = 'k', c ='red', s=100, label ="Start")
graph.scatter(90,100, marker = "s", ec = 'k', c ='red', s =100,label="Target")
graph.grid(linestyle=':')
graph.xlim(0,100)
graph.ylim(0,100)
graph.xlabel('x (m)',size = '14')
graph.ylabel('y (m)',size = '14')
graph.gca().set_aspect('equal', adjustable='box')
graph.show()
