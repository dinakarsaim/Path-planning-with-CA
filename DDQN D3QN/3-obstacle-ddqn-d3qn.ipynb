# %%
# !python /kaggle/input/113333/env.py

# %%
# !python /kaggle/input/113333/Agent.py

# %%
# !python /kaggle/input/113333/D3QN_train.py
# Out:
# Episode 0, Reward: -8406.5, Steps: 1651, Epsilon: 0.598
# Episode 10, Reward: -995.5, Steps: 195, Epsilon: 0.578
# Episode 20, Reward: -544.5, Steps: 80, Epsilon: 0.5579999999999999
# Episode 30, Reward: -160.5, Steps: 40, Epsilon: 0.5379999999999999
# Episode 40, Reward: -160.0, Steps: 40, Epsilon: 0.5179999999999999
# Episode 50, Reward: -29.5, Steps: 26, Epsilon: 0.4979999999999999
# Episode 60, Reward: -64.0, Steps: 39, Epsilon: 0.47799999999999987
# Episode 70, Reward: -82.0, Steps: 38, Epsilon: 0.45799999999999985
# Episode 80, Reward: -134.5, Steps: 35, Epsilon: 0.43799999999999983
# Episode 90, Reward: -95.5, Steps: 34, Epsilon: 0.4179999999999998
# Episode 100, Reward: -147.5, Steps: 31, Epsilon: 0.3979999999999998
# Episode 110, Reward: -133.0, Steps: 33, Epsilon: 0.3779999999999998
# Episode 120, Reward: -85.5, Steps: 27, Epsilon: 0.35799999999999976
# Episode 130, Reward: -148.5, Steps: 31, Epsilon: 0.33799999999999975
# Episode 140, Reward: -107.5, Steps: 28, Epsilon: 0.3179999999999997
# Episode 150, Reward: -44.5, Steps: 24, Epsilon: 0.2979999999999997
# Episode 160, Reward: -40.5, Steps: 20, Epsilon: 0.2779999999999997
# Episode 170, Reward: -165.5, Steps: 80, Epsilon: 0.2579999999999997
# Episode 180, Reward: -104.5, Steps: 26, Epsilon: 0.23799999999999966
# Episode 190, Reward: -34.5, Steps: 32, Epsilon: 0.21799999999999964
# Episode 200, Reward: -24.5, Steps: 24, Epsilon: 0.19799999999999962
# Episode 210, Reward: -51.5, Steps: 29, Epsilon: 0.1779999999999996
# Episode 220, Reward: -2.5, Steps: 20, Epsilon: 0.15799999999999959
# Episode 230, Reward: -3.0, Steps: 21, Epsilon: 0.13799999999999957
# Episode 240, Reward: -2.5, Steps: 20, Epsilon: 0.11799999999999955
# Episode 250, Reward: -22.5, Steps: 20, Epsilon: 0.09799999999999953
# Episode 260, Reward: -23.0, Steps: 20, Epsilon: 0.07799999999999951
# Episode 270, Reward: -30.0, Steps: 29, Epsilon: 0.057999999999999496
# Episode 280, Reward: -0.5, Steps: 18, Epsilon: 0.03799999999999948
# Episode 290, Reward: -2.0, Steps: 18, Epsilon: 0.01799999999999946
# []

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/d3qn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[3]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('accumulated rewards')
graph.title('d3qn')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/d3qn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[1]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('steps taken')
graph.title('d3qn')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/d3qn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[2]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('time taken(ms)')
graph.title('d3qn')
graph.legend()
graph.show()

# %%
# %cd /kaggle/input/113333
# Out:
# /kaggle/input/113333

# %%
import csv
import matplotlib.pyplot as graph
import numpy
from env import obstacle_width
from env import Anish
obcoords = Anish()
x_o = obcoords.xpart
y_o = obcoords.ypart
with open('/kaggle/working/d3qn_final_path.csv') as file:
    reader  = csv.reader(file)
    for row in reader:
        finalx = numpy.array(list(map(int,row)))
        break
    for row in reader:
        finaly = numpy.array(list(map(int,row)))
        break
graph.figure()
graph.quiver(finalx[:-1],finaly[:-1],finalx[1:]-finalx[:-1],finaly[1:]-finaly[:-1], scale_units='xy', angles='xy', scale=1, color='black', label='sarsa')
for i in range(len(x_o)):
    rectangle = graph.Rectangle(( 10* (x_o[i]-0.5), 10*(10 - y_o[i] -0.5)), obstacle_width, obstacle_width, fc='blue',ec="blue")
    graph.gca().add_patch(rectangle)
graph.scatter(10,0, marker = "s", ec = 'k', c ='red', s=100, label ="Start")
graph.scatter(90,100, marker = "s", ec = 'k', c ='red', s =100,label="Target")
graph.grid(linestyle=':')
graph.xlim(0,100)
graph.ylim(0,100)
graph.xlabel('x (m)',size = '14')
graph.ylabel('y (m)',size = '14')
graph.gca().set_aspect('equal', adjustable='box')
graph.show()

# %%
# !python /kaggle/input/113333/AgentWithCA.py

# %%
# !python /kaggle/input/113333/D3QNWithCA.py
# Out:
# Episode 0, Reward: -107.0, Steps: 26, Epsilon: 0.598
# Episode 10, Reward: -773.5, Steps: 177, Epsilon: 0.578
# Episode 20, Reward: -153.0, Steps: 37, Epsilon: 0.5579999999999999
# Episode 30, Reward: -1578.5, Steps: 359, Epsilon: 0.5379999999999999
# Episode 40, Reward: -257.0, Steps: 77, Epsilon: 0.5179999999999999
# Episode 50, Reward: -57.5, Steps: 34, Epsilon: 0.4979999999999999
# Episode 60, Reward: -109.0, Steps: 31, Epsilon: 0.47799999999999987
# Episode 70, Reward: -101.0, Steps: 39, Epsilon: 0.45799999999999985
# Episode 80, Reward: -237.5, Steps: 43, Epsilon: 0.43799999999999983
# Episode 90, Reward: -100.0, Steps: 39, Epsilon: 0.4179999999999998
# Episode 100, Reward: -86.5, Steps: 26, Epsilon: 0.3979999999999998
# Episode 110, Reward: -64.0, Steps: 23, Epsilon: 0.3779999999999998
# Episode 120, Reward: -94.0, Steps: 34, Epsilon: 0.35799999999999976
# Episode 130, Reward: -8.0, Steps: 25, Epsilon: 0.33799999999999975
# Episode 140, Reward: -53.5, Steps: 30, Epsilon: 0.3179999999999997
# Episode 150, Reward: -52.0, Steps: 29, Epsilon: 0.2979999999999997
# Episode 160, Reward: -77.0, Steps: 18, Epsilon: 0.2779999999999997
# Episode 170, Reward: -40.5, Steps: 20, Epsilon: 0.2579999999999997
# Episode 180, Reward: -23.5, Steps: 22, Epsilon: 0.23799999999999966
# Episode 190, Reward: -44.5, Steps: 24, Epsilon: 0.21799999999999964
# Episode 200, Reward: -26.0, Steps: 24, Epsilon: 0.19799999999999962
# Episode 210, Reward: -34.5, Steps: 15, Epsilon: 0.1779999999999996
# Episode 220, Reward: -44.5, Steps: 23, Epsilon: 0.15799999999999959
# Episode 230, Reward: -27.0, Steps: 26, Epsilon: 0.13799999999999957
# Episode 240, Reward: -1.0, Steps: 19, Epsilon: 0.11799999999999955
# Episode 250, Reward: -2.0, Steps: 20, Epsilon: 0.09799999999999953
# Episode 260, Reward: -24.5, Steps: 22, Epsilon: 0.07799999999999951
# Episode 270, Reward: -22.5, Steps: 21, Epsilon: 0.057999999999999496
# Episode 280, Reward: -39.0, Steps: 19, Epsilon: 0.03799999999999948
# Episode 290, Reward: -0.5, Steps: 18, Epsilon: 0.01799999999999946
# []

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/d3qn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[3]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('accumulated rewards')
graph.title('d3qn with ca')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/d3qn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[1]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('steps taken')
graph.title('d3qn with CA')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/d3qn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[2]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('time taken')
graph.title('d3qn with CA')
graph.legend()
graph.show()

# %%
# %cd /kaggle/input/113333
# Out:
# /kaggle/input/113333

# %%
import csv
import matplotlib.pyplot as graph
import numpy
from env import obstacle_width
from env import Anish
obcoords = Anish()
x_o = obcoords.xpart
y_o = obcoords.ypart
with open('/kaggle/working/d3qn_withCA_final_path.csv') as file:
    reader  = csv.reader(file)
    for row in reader:
        finalx = numpy.array(list(map(int,row)))
        break
    for row in reader:
        finaly = numpy.array(list(map(int,row)))
        break
graph.figure()
graph.quiver(finalx[:-1],finaly[:-1],finalx[1:]-finalx[:-1],finaly[1:]-finaly[:-1], scale_units='xy', angles='xy', scale=1, color='black', label='sarsa')
for i in range(len(x_o)):
    rectangle = graph.Rectangle(( 10* (x_o[i]-0.5), 10*(10 - y_o[i] -0.5)), obstacle_width, obstacle_width, fc='blue',ec="blue")
    graph.gca().add_patch(rectangle)
graph.scatter(10,0, marker = "s", ec = 'k', c ='red', s=100, label ="Start")
graph.scatter(90,100, marker = "s", ec = 'k', c ='red', s =100,label="Target")
graph.grid(linestyle=':')
graph.xlim(0,100)
graph.ylim(0,100)
graph.xlabel('x (m)',size = '14')
graph.ylabel('y (m)',size = '14')
graph.gca().set_aspect('equal', adjustable='box')
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
d3qnlist = list()
d3qncalist = list()
with open('/kaggle/working/d3qn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:d3qncalist.append(float(row[3]))
with open('/kaggle/working/d3qn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:d3qnlist.append(float(row[3]))
graph.plot(range(len(d3qnlist)),d3qnlist,color='blue')
graph.plot(range(len(d3qncalist)),d3qncalist,color='red')
graph.xlabel('ep')
graph.ylabel('accumulated rewards')
graph.title('d3qn vs d3qn with ca')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
d3qnlist = list()
d3qncalist = list()
with open('/kaggle/working/d3qn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:d3qncalist.append(float(row[1]))
with open('/kaggle/working/d3qn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:d3qnlist.append(float(row[1]))
graph.plot(range(len(d3qnlist)),d3qnlist,color='blue')
graph.plot(range(len(d3qncalist)),d3qncalist,color='red')
graph.xlabel('ep')
graph.ylabel('steps taken')
graph.title('d3qn vs d3qn with ca')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
d3qnlist = list()
d3qncalist = list()
with open('/kaggle/working/d3qn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:d3qncalist.append(float(row[2]))
with open('/kaggle/working/d3qn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:d3qnlist.append(float(row[2]))
graph.plot(range(len(d3qnlist)),d3qnlist,color='blue')
graph.plot(range(len(d3qncalist)),d3qncalist,color='red')
graph.xlabel('ep')
graph.ylabel('time taken')
graph.title('d3qn vs d3qn with ca')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
import numpy
from env import obstacle_width
from env import Anish
obcoords = Anish()
x_o = obcoords.xpart
y_o = obcoords.ypart
with open('/kaggle/working/d3qn_final_path.csv') as file:
    reader  = csv.reader(file)
    for row in reader:
        finalx = numpy.array(list(map(int,row)))
        break
    for row in reader:
        finaly = numpy.array(list(map(int,row)))
        break
graph.figure()
graph.quiver(finalx[:-1],finaly[:-1],finalx[1:]-finalx[:-1],finaly[1:]-finaly[:-1], scale_units='xy', angles='xy', scale=1, color='blue')
with open('/kaggle/working/d3qn_withCA_final_path.csv') as file:
    reader  = csv.reader(file)
    for row in reader:
        finalx = numpy.array(list(map(int,row)))
        break
    for row in reader:
        finaly = numpy.array(list(map(int,row)))
        break
graph.quiver(finalx[:-1],finaly[:-1],finalx[1:]-finalx[:-1],finaly[1:]-finaly[:-1], scale_units='xy', angles='xy', scale=1, color='red')
for i in range(len(x_o)):
    rectangle = graph.Rectangle(( 10* (x_o[i]-0.5), 10*(10 - y_o[i] -0.5)), obstacle_width, obstacle_width, fc='blue',ec="blue")
    graph.gca().add_patch(rectangle)
graph.scatter(10,0, marker = "s", ec = 'k', c ='red', s=100, label ="Start")
graph.scatter(90,100, marker = "s", ec = 'k', c ='red', s =100,label="Target")
graph.grid(linestyle=':')
graph.xlim(0,100)
graph.ylim(0,100)
graph.xlabel('x (m)',size = '14')
graph.ylabel('y (m)',size = '14')
graph.gca().set_aspect('equal', adjustable='box')
graph.show()

# %%
# !python /kaggle/input/113333/DDQN_train.py
# Out:
# Episode 0, Reward: -3927.5, Steps: 1009, Epsilon: 0.598
# Episode 10, Reward: -1733.0, Steps: 451, Epsilon: 0.578
# Episode 20, Reward: -192.0, Steps: 40, Epsilon: 0.5579999999999999
# Episode 30, Reward: -80.0, Steps: 35, Epsilon: 0.5379999999999999
# Episode 40, Reward: -416.5, Steps: 65, Epsilon: 0.5179999999999999
# Episode 50, Reward: -413.5, Steps: 78, Epsilon: 0.4979999999999999
# Episode 60, Reward: -107.5, Steps: 44, Epsilon: 0.47799999999999987
# Episode 70, Reward: -136.0, Steps: 37, Epsilon: 0.45799999999999985
# Episode 80, Reward: -96.5, Steps: 35, Epsilon: 0.43799999999999983
# Episode 90, Reward: -155.0, Steps: 36, Epsilon: 0.4179999999999998
# Episode 100, Reward: -104.0, Steps: 26, Epsilon: 0.3979999999999998
# Episode 110, Reward: -181.0, Steps: 43, Epsilon: 0.3779999999999998
# Episode 120, Reward: -114.0, Steps: 34, Epsilon: 0.35799999999999976
# Episode 130, Reward: -76.0, Steps: 32, Epsilon: 0.33799999999999975
# Episode 140, Reward: -6.5, Steps: 24, Epsilon: 0.3179999999999997
# Episode 150, Reward: -83.5, Steps: 25, Epsilon: 0.2979999999999997
# Episode 160, Reward: -89.0, Steps: 29, Epsilon: 0.2779999999999997
# Episode 170, Reward: -142.0, Steps: 42, Epsilon: 0.2579999999999997
# Episode 180, Reward: -41.5, Steps: 21, Epsilon: 0.23799999999999966
# Episode 190, Reward: -21.0, Steps: 19, Epsilon: 0.21799999999999964
# Episode 200, Reward: -43.5, Steps: 23, Epsilon: 0.19799999999999962
# Episode 210, Reward: -6.0, Steps: 22, Epsilon: 0.1779999999999996
# Episode 220, Reward: -82.5, Steps: 22, Epsilon: 0.15799999999999959
# Episode 230, Reward: -23.0, Steps: 22, Epsilon: 0.13799999999999957
# Episode 240, Reward: -24.5, Steps: 23, Epsilon: 0.11799999999999955
# Episode 250, Reward: -1.5, Steps: 20, Epsilon: 0.09799999999999953
# Episode 260, Reward: -28.0, Steps: 24, Epsilon: 0.07799999999999951
# Episode 270, Reward: -24.0, Steps: 22, Epsilon: 0.057999999999999496
# Episode 280, Reward: -12.5, Steps: 12, Epsilon: 0.03799999999999948
# Episode 290, Reward: -1.0, Steps: 19, Epsilon: 0.01799999999999946
# []

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/ddqn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[3]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('accumulated rewards')
graph.title('ddqn')
graph.legend()
graph.show()


import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/ddqn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[1]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('steps taken')
graph.title('ddqn')
graph.legend()
graph.show()

import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/ddqn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[2]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('time taken(ms)')
graph.title('ddqn')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
import numpy
from env import obstacle_width
from env import Anish
obcoords = Anish()
x_o = obcoords.xpart
y_o = obcoords.ypart
with open('/kaggle/working/ddqn_final_path.csv') as file:
    reader  = csv.reader(file)
    for row in reader:
        finalx = numpy.array(list(map(int,row)))
        break
    for row in reader:
        finaly = numpy.array(list(map(int,row)))
        break
graph.figure()
graph.quiver(finalx[:-1],finaly[:-1],finalx[1:]-finalx[:-1],finaly[1:]-finaly[:-1], scale_units='xy', angles='xy', scale=1, color='black', label='sarsa')
for i in range(len(x_o)):
    rectangle = graph.Rectangle(( 10* (x_o[i]-0.5), 10*(10 - y_o[i] -0.5)), obstacle_width, obstacle_width, fc='blue',ec="blue")
    graph.gca().add_patch(rectangle)
graph.scatter(10,0, marker = "s", ec = 'k', c ='red', s=100, label ="Start")
graph.scatter(90,100, marker = "s", ec = 'k', c ='red', s =100,label="Target")
graph.grid(linestyle=':')
graph.xlim(0,100)
graph.ylim(0,100)
graph.xlabel('x (m)',size = '14')
graph.ylabel('y (m)',size = '14')
graph.gca().set_aspect('equal', adjustable='box')
graph.show()

# %%
# !python /kaggle/input/113333/DDQNWithCA.py
# Out:
# Episode 0, Reward: -1937.5, Steps: 437, Epsilon: 0.598
# Episode 10, Reward: -805.0, Steps: 161, Epsilon: 0.578
# Episode 20, Reward: -193.0, Steps: 88, Epsilon: 0.5579999999999999
# Episode 30, Reward: -253.5, Steps: 55, Epsilon: 0.5379999999999999
# Episode 40, Reward: -279.0, Steps: 45, Epsilon: 0.5179999999999999
# Episode 50, Reward: -251.5, Steps: 66, Epsilon: 0.4979999999999999
# Episode 60, Reward: -81.0, Steps: 36, Epsilon: 0.47799999999999987
# Episode 70, Reward: -189.5, Steps: 48, Epsilon: 0.45799999999999985
# Episode 80, Reward: -116.5, Steps: 35, Epsilon: 0.43799999999999983
# Episode 90, Reward: -191.0, Steps: 36, Epsilon: 0.4179999999999998
# Episode 100, Reward: -174.0, Steps: 35, Epsilon: 0.3979999999999998
# Episode 110, Reward: -65.5, Steps: 26, Epsilon: 0.3779999999999998
# Episode 120, Reward: -120.5, Steps: 54, Epsilon: 0.35799999999999976
# Episode 130, Reward: -45.5, Steps: 23, Epsilon: 0.33799999999999975
# Episode 140, Reward: -123.5, Steps: 27, Epsilon: 0.3179999999999997
# Episode 150, Reward: -26.5, Steps: 23, Epsilon: 0.2979999999999997
# Episode 160, Reward: -23.0, Steps: 23, Epsilon: 0.2779999999999997
# Episode 170, Reward: -90.0, Steps: 30, Epsilon: 0.2579999999999997
# Episode 180, Reward: -3.5, Steps: 20, Epsilon: 0.23799999999999966
# Episode 190, Reward: -63.5, Steps: 23, Epsilon: 0.21799999999999964
# Episode 200, Reward: -64.0, Steps: 25, Epsilon: 0.19799999999999962
# Episode 210, Reward: -43.0, Steps: 23, Epsilon: 0.1779999999999996
# Episode 220, Reward: -5.5, Steps: 24, Epsilon: 0.15799999999999959
# Episode 230, Reward: -5.5, Steps: 23, Epsilon: 0.13799999999999957
# Episode 240, Reward: -23.0, Steps: 21, Epsilon: 0.11799999999999955
# Episode 250, Reward: -3.5, Steps: 20, Epsilon: 0.09799999999999953
# Episode 260, Reward: -23.0, Steps: 21, Epsilon: 0.07799999999999951
# Episode 270, Reward: -0.5, Steps: 18, Epsilon: 0.057999999999999496
# Episode 280, Reward: -7.0, Steps: 25, Epsilon: 0.03799999999999948
# Episode 290, Reward: -1.0, Steps: 19, Epsilon: 0.01799999999999946
# []

# %%
import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/ddqn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[3]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('accumulated rewards')
graph.title('ddqn with CA')
graph.legend()
graph.show()


import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/ddqn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[1]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('steps taken')
graph.title('ddqn with CA')
graph.legend()
graph.show()

import csv
import matplotlib.pyplot as graph
ddqnlist = list()
with open('/kaggle/working/ddqn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:ddqnlist.append(float(row[2]))
graph.plot(range(len(ddqnlist)),ddqnlist,color='black')
graph.xlabel('ep')
graph.ylabel('time taken(ms)')
graph.title('ddqn with CA')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
import numpy
from env import obstacle_width
from env import Anish
obcoords = Anish()
x_o = obcoords.xpart
y_o = obcoords.ypart
with open('/kaggle/working/ddqn_withCA_final_path.csv') as file:
    reader  = csv.reader(file)
    for row in reader:
        finalx = numpy.array(list(map(int,row)))
        break
    for row in reader:
        finaly = numpy.array(list(map(int,row)))
        break
graph.figure()
graph.quiver(finalx[:-1],finaly[:-1],finalx[1:]-finalx[:-1],finaly[1:]-finaly[:-1], scale_units='xy', angles='xy', scale=1, color='black', label='sarsa')
for i in range(len(x_o)):
    rectangle = graph.Rectangle(( 10* (x_o[i]-0.5), 10*(10 - y_o[i] -0.5)), obstacle_width, obstacle_width, fc='blue',ec="blue")
    graph.gca().add_patch(rectangle)
graph.scatter(10,0, marker = "s", ec = 'k', c ='red', s=100, label ="Start")
graph.scatter(90,100, marker = "s", ec = 'k', c ='red', s =100,label="Target")
graph.grid(linestyle=':')
graph.xlim(0,100)
graph.ylim(0,100)
graph.xlabel('x (m)',size = '14')
graph.ylabel('y (m)',size = '14')
graph.gca().set_aspect('equal', adjustable='box')
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
d3qnlist = list()
d3qncalist = list()
with open('/kaggle/working/ddqn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:d3qncalist.append(float(row[3]))
with open('/kaggle/working/ddqn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:d3qnlist.append(float(row[3]))
graph.plot(range(len(d3qnlist)),d3qnlist,color='blue')
graph.plot(range(len(d3qncalist)),d3qncalist,color='red')
graph.xlabel('ep')
graph.ylabel('accumulated rewards')
graph.title('ddqn vs ddqn with ca')
graph.legend()
graph.show()

import csv
import matplotlib.pyplot as graph
d3qnlist = list()
d3qncalist = list()
with open('/kaggle/working/ddqn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:d3qncalist.append(float(row[1]))
with open('/kaggle/working/ddqn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:d3qnlist.append(float(row[1]))
graph.plot(range(len(d3qnlist)),d3qnlist,color='blue')
graph.plot(range(len(d3qncalist)),d3qncalist,color='red')
graph.xlabel('ep')
graph.ylabel('steps taken')
graph.title('ddqn vs ddqn with ca')
graph.legend()
graph.show()

import csv
import matplotlib.pyplot as graph
d3qnlist = list()
d3qncalist = list()
with open('/kaggle/working/ddqn_withCA_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:d3qncalist.append(float(row[2]))
with open('/kaggle/working/ddqn_results.csv') as file:
    reader = csv.reader(file)
    counter = -1
    for row in reader:
        if counter == 0:break
        counter += 1
    for row in reader:d3qnlist.append(float(row[2]))
graph.plot(range(len(d3qnlist)),d3qnlist,color='blue')
graph.plot(range(len(d3qncalist)),d3qncalist,color='red')
graph.xlabel('ep')
graph.ylabel('time taken')
graph.title('ddqn vs ddqn with ca')
graph.legend()
graph.show()

# %%
import csv
import matplotlib.pyplot as graph
import numpy
from env import obstacle_width
from env import Anish
obcoords = Anish()
x_o = obcoords.xpart
y_o = obcoords.ypart
with open('/kaggle/working/ddqn_final_path.csv') as file:
    reader  = csv.reader(file)
    for row in reader:
        finalx = numpy.array(list(map(int,row)))
        break
    for row in reader:
        finaly = numpy.array(list(map(int,row)))
        break
graph.figure()
graph.quiver(finalx[:-1],finaly[:-1],finalx[1:]-finalx[:-1],finaly[1:]-finaly[:-1], scale_units='xy', angles='xy', scale=1, color='blue')
with open('/kaggle/working/ddqn_withCA_final_path.csv') as file:
    reader  = csv.reader(file)
    for row in reader:
        finalx = numpy.array(list(map(int,row)))
        break
    for row in reader:
        finaly = numpy.array(list(map(int,row)))
        break
graph.quiver(finalx[:-1],finaly[:-1],finalx[1:]-finalx[:-1],finaly[1:]-finaly[:-1], scale_units='xy', angles='xy', scale=1, color='red')
for i in range(len(x_o)):
    rectangle = graph.Rectangle(( 10* (x_o[i]-0.5), 10*(10 - y_o[i] -0.5)), obstacle_width, obstacle_width, fc='blue',ec="blue")
    graph.gca().add_patch(rectangle)
graph.scatter(10,0, marker = "s", ec = 'k', c ='red', s=100, label ="Start")
graph.scatter(90,100, marker = "s", ec = 'k', c ='red', s =100,label="Target")
graph.grid(linestyle=':')
graph.xlim(0,100)
graph.ylim(0,100)
graph.xlabel('x (m)',size = '14')
graph.ylabel('y (m)',size = '14')
graph.gca().set_aspect('equal', adjustable='box')
graph.show()
